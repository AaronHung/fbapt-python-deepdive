# %% [markdown]
# ### Aaron's Nord Deep Theme

# %% [markdown]
# # 🎨 Nord Deep - Aaron Extracted Token Colors
#
# 以下是 Aaron 從 VS Code Nord Deep Theme 提取的 **唯一 HEX 顏色**，和它們對應的語法高亮元件：
#
# | 顏色 | HEX | 對應的 `Token` 元件 |
# |------|-----|------------------|
# | <span style="color:#BF616A">⬤</span> | `#BF616A` | <font color=#BF616A>Constant Numeric, Editor Error, Markup Deleted, Token Error</font> |
# | <span style="color:#D08770">⬤</span> | `#D08770` | <font color=#D08770>CSS Media Queries, JavaScript Decorator, Python Decorator, XML Entity Name Tag Namespace</font> |
# | <span style="color:#EBCB8B">⬤</span> | `#EBCB8B` | <font color=#EBCB8B>Constant Character, Constant Character Escape, Constant Regexp, Markup Changed, String Regexp, Token Warning</font> |
# | <span style="color:#A3BE8C">⬤</span> | `#A3BE8C` | <font color=#A3BE8C>Markup Inserted, String</font> |
# | <span style="color:#8FBCBB">⬤</span> | `#8FBCBB` | <font color=#8FBCBB>Entity Name Class/Type, Entity Other Attribute Name, Entity Other Inherited Class, Source Elixir Variable Other, Support Type, Support Type Exception</font> |
# | <span style="color:#88C0D0">⬤</span> | `#88C0D0` | <font color=#88C0D0>Entity Name Function, Editor Suggest Widget Highlight, Markup Heading, Meta Function-Call, Support Function, Token Info</font> |
# | <span style="color:#81A1C1">⬤</span> | `#81A1C1` | <font color=#81A1C1>Constant Language, Entity Name Tag, Keyword, Keyword Operator, Punctuation Definition Tag, Storage, Variable Language</font> |
# | <span style="color:#5E81AC">⬤</span> | `#5E81AC` | <font color=#5E81AC>Meta Preprocessor, Conditional Directive, XML Keyword Other Doctype</font> |
# | <span style="color:#B48EAD">⬤</span> | `#B48EAD` | <font color=#B48EAD>CSS Constant Other Color RGB Value, Token Debug</font> |
# | <span style="color:#ECEFF4">⬤</span> | `#ECEFF4` | <font color=#ECEFF4>Punctuation, Punctuation Section, JavaScript Interpolated String Template Punctuation Functions</font> |
# | <span style="color:#D8DEE9">⬤</span> | `#D8DEE9` | <font color=#D8DEE9>Invalid Deprecated, Invalid Illegal, Variable Other, Variable Parameter, Markdown String Other Link Description/Title</font> |
# | <span style="color:#78849b">⬤</span> | `#78849b` | <font color=#78849b>Comment, punctuation.definition.comment</font> |
#
# ---
#
# | 顏色 | HEX | 對應的 `UI` 元件 |
# |------|-----|---------------|
# | <span style="color:#bf616a">⬤</span> | `#bf616a` | <font color=#bf616a>editorError.foreground, editorGutter.deletedBackground, errorForeground</font> |
# | <span style="color:#ebcb8b">⬤</span> | `#ebcb8b` | <font color=#ebcb8b>editorGutter.modifiedBackground, terminal.ansiBrightYellow, terminal.ansiYellow</font> |
# | <span style="color:#a3be8c">⬤</span> | `#a3be8c` | <font color=#a3be8c>editorGutter.addedBackground, terminal.ansiBrightGreen, terminal.ansiGreen</font> |
# | <span style="color:#8fbcbb">⬤</span> | `#8fbcbb` | <font color=#8fbcbb>gitDecoration.submoduleResourceForeground, terminal.ansiBrightCyan, terminal.ansiCyan</font> |
# | <span style="color:#88c0d0">⬤</span> | `#88c0d0` | <font color=#88c0d0>activityBar.activeBorder, editorBracketMatch.border, progressBar.background</font> |
# | <span style="color:#81a1c1">⬤</span> | `#81a1c1` | <font color=#81a1c1>editorOverviewRuler.infoForeground, terminal.ansiBrightBlue, terminal.ansiBlue</font> |
# | <span style="color:#5e81ac">⬤</span> | `#5e81ac` | <font color=#5e81ac>gitDecoration.conflictingResourceForeground, inputOption.activeBackground, statusBar.debuggingBackground</font> |
# | <span style="color:#b48ead">⬤</span> | `#b48ead` | <font color=#b48ead>terminal.ansiBrightMagenta, terminal.ansiMagenta</font> |
# | <span style="color:#a08bb1">⬤</span> | `#a08bb1` | <font color=#a08bb1>activityBar, background</font> |
# | <span style="color:#876d9d">⬤</span> | `#876d9d` | <font color=#876d9d>statusBar.background, titleBar.activeBackground, statusBarItem.remoteBackground</font> |
# | <span style="color:#eceff4">⬤</span> | `#eceff4` | <font color=#eceff4>terminal.ansiBrightWhite</font> |
# | <span style="color:#e7e7e7">⬤</span> | `#e7e7e7` | <font color=#e7e7e7>statusBar.foreground, titleBar.activeForeground, statusBarItem.remoteForeground</font> |
# | <span style="color:#e5e9f0">⬤</span> | `#e5e9f0` | <font color=#e5e9f0>terminal.ansiWhite</font> |
# | <span style="color:#d9d0c6">⬤</span> | `#d9d0c6` | <font color=#d9d0c6>activityBarBadge.background</font> |
# | <span style="color:#d8dee9">⬤</span> | `#d8dee9` | <font color=#d8dee9>editor.foreground, button.foreground, input.foreground, list.focusForeground</font> |
# | <span style="color:#4c566a">⬤</span> | `#4c566a` | <font color=#4c566a>button.hoverBackground, editorCodeLens.foreground, editorLineNumber.foreground</font> |
# | <span style="color:#292e39">⬤</span> | `#292e39` | <font color=#292e39>dropdown.background, editorHoverWidget.background, input.background, statusBar.noFolderBackground</font> |
# | <span style="color:#1d2129">⬤</span> | `#1d2129` | <font color=#1d2129>editor.background, editorGroupHeader.noTabsBackground, terminal.background</font> |
# | <span style="color:#15202b">⬤</span> | `#15202b` | <font color=#15202b>activityBar.foreground, activityBarBadge.foreground</font> |
# | <span style="color:#00000066">⬤</span> | `#00000066` | <font color=#00000066>scrollbar.shadow, widget.shadow</font> |

# %% [markdown]
# # 🎨 Nord Deep - Aaron Extracted Token Colors
#
# 以下是 Aaron 從 VS Code Nord Deep Theme 提取的 **唯一 HEX 顏色**，和它們對應的語法高亮元件：
#
# | 顏色 | HEX | 對應的 `Token` 元件 |
# |------|-----|------------------|
# | <span style="color:#BF616A">⬤</span> | `#BF616A` | Constant Numeric, Editor Error, Markup Deleted, Token Error |
# | <span style="color:#D08770">⬤</span> | `#D08770` | CSS Media Queries, JavaScript Decorator, Python Decorator, XML Entity Name Tag Namespace |
# | <span style="color:#EBCB8B">⬤</span> | `#EBCB8B` | Constant Character, Constant Character Escape, Constant Regexp, Markup Changed, String Regexp, Token Warning |
# | <span style="color:#A3BE8C">⬤</span> | `#A3BE8C` | Markup Inserted, String |
# | <span style="color:#8FBCBB">⬤</span> | `#8FBCBB` | Entity Name Class/Type, Entity Other Attribute Name, Entity Other Inherited Class, Source Elixir Variable Other, Support Type, Support Type Exception |
# | <span style="color:#88C0D0">⬤</span> | `#88C0D0` | Entity Name Function, Editor Suggest Widget Highlight, Markup Heading, Meta Function-Call, Support Function, Token Info |
# | <span style="color:#81A1C1">⬤</span> | `#81A1C1` | Constant Language, Entity Name Tag, Keyword, Keyword Operator, Punctuation Definition Tag, Storage, Variable Language |
# | <span style="color:#5E81AC">⬤</span> | `#5E81AC` | Meta Preprocessor, Conditional Directive, XML Keyword Other Doctype |
# | <span style="color:#B48EAD">⬤</span> | `#B48EAD` | CSS Constant Other Color RGB Value, Token Debug |
# | <span style="color:#ECEFF4">⬤</span> | `#ECEFF4` | Punctuation, Punctuation Section, JavaScript Interpolated String Template Punctuation Functions |
# | <span style="color:#D8DEE9">⬤</span> | `#D8DEE9` | Invalid Deprecated, Invalid Illegal, Variable Other, Variable Parameter, Markdown String Other Link Description/Title |
# | <span style="color:#78849b">⬤</span> | `#78849b` | Comment, punctuation.definition.comment |
#
# ---

# %% [markdown]
# | 顏色 | HEX | 對應的 `UI` 元件 |
# |------|-----|---------------|
# | <span style="color:#bf616a">⬤</span> | `#bf616a` | editorError.foreground, editorGutter.deletedBackground, errorForeground |
# | <span style="color:#ebcb8b">⬤</span> | `#ebcb8b` | editorGutter.modifiedBackground, terminal.ansiBrightYellow, terminal.ansiYellow |
# | <span style="color:#a3be8c">⬤</span> | `#a3be8c` | editorGutter.addedBackground, terminal.ansiBrightGreen, terminal.ansiGreen |
# | <span style="color:#8fbcbb">⬤</span> | `#8fbcbb` | gitDecoration.submoduleResourceForeground, terminal.ansiBrightCyan, terminal.ansiCyan |
# | <span style="color:#88c0d0">⬤</span> | `#88c0d0` | activityBar.activeBorder, editorBracketMatch.border, progressBar.background |
# | <span style="color:#81a1c1">⬤</span> | `#81a1c1` | editorOverviewRuler.infoForeground, terminal.ansiBrightBlue, terminal.ansiBlue |
# | <span style="color:#5e81ac">⬤</span> | `#5e81ac` | gitDecoration.conflictingResourceForeground, inputOption.activeBackground, statusBar.debuggingBackground |
# | <span style="color:#b48ead">⬤</span> | `#b48ead` | terminal.ansiBrightMagenta, terminal.ansiMagenta |
# | <span style="color:#a08bb1">⬤</span> | `#a08bb1` | activityBar, background |
# | <span style="color:#876d9d">⬤</span> | `#876d9d` | statusBar.background, titleBar.activeBackground, statusBarItem.remoteBackground |
# | <span style="color:#eceff4">⬤</span> | `#eceff4` | terminal.ansiBrightWhite |
# | <span style="color:#e7e7e7">⬤</span> | `#e7e7e7` | statusBar.foreground, titleBar.activeForeground, statusBarItem.remoteForeground |
# | <span style="color:#e5e9f0">⬤</span> | `#e5e9f0` | terminal.ansiWhite |
# | <span style="color:#d9d0c6">⬤</span> | `#d9d0c6` | activityBarBadge.background |
# | <span style="color:#d8dee9">⬤</span> | `#d8dee9` | editor.foreground, button.foreground, input.foreground, list.focusForeground |
# | <span style="color:#4c566a">⬤</span> | `#4c566a` | button.hoverBackground, editorCodeLens.foreground, editorLineNumber.foreground |
# | <span style="color:#292e39">⬤</span> | `#292e39` | dropdown.background, editorHoverWidget.background, input.background, statusBar.noFolderBackground |
# | <span style="color:#1d2129">⬤</span> | `#1d2129` | editor.background, editorGroupHeader.noTabsBackground, terminal.background |
# | <span style="color:#15202b">⬤</span> | `#15202b` | activityBar.foreground, activityBarBadge.foreground |
# | <span style="color:#00000066">⬤</span> | `#00000066` | scrollbar.shadow, widget.shadow |

# %% [markdown]
# # 🎨 Nord Deep - Aaron Extracted Token Colors
#
# 以下是 Aaron 從 VS Code Nord Deep Theme 提取的 **唯一 HEX 顏色**，和它們對應的語法高亮元件：
#
# | 顏色 | HEX | 對應的 `Token` 元件 |
# |------|-----|------------------|
# | <span style="color:#BF616A">⬤</span> | `#BF616A` | <font color=#BF616A>Constant Numeric, Editor Error, Markup Deleted, Token Error</font> |
# | <span style="color:#D08770">⬤</span> | `#D08770` | <font color=#D08770>CSS Media Queries, JavaScript Decorator, Python Decorator, XML Entity Name Tag Namespace</font> |
# | <span style="color:#EBCB8B">⬤</span> | `#EBCB8B` | <font color=#EBCB8B>Constant Character, Constant Character Escape, Constant Regexp, Markup Changed, String Regexp, Token Warning</font> |
# | <span style="color:#A3BE8C">⬤</span> | `#A3BE8C` | <font color=#A3BE8C>Markup Inserted, String</font> |
# | <span style="color:#8FBCBB">⬤</span> | `#8FBCBB` | <font color=#8FBCBB>Entity Name Class/Type, Entity Other Attribute Name, Entity Other Inherited Class, Source Elixir Variable Other, Support Type, Support Type Exception</font> |
# | <span style="color:#88C0D0">⬤</span> | `#88C0D0` | <font color=#88C0D0>Entity Name Function, Editor Suggest Widget Highlight, Markup Heading, Meta Function-Call, Support Function, Token Info</font> |
# | <span style="color:#81A1C1">⬤</span> | `#81A1C1` | <font color=#81A1C1>Constant Language, Entity Name Tag, Keyword, Keyword Operator, Punctuation Definition Tag, Storage, Variable Language</font> |
# | <span style="color:#5E81AC">⬤</span> | `#5E81AC` | <font color=#5E81AC>Meta Preprocessor, Conditional Directive, XML Keyword Other Doctype</font> |
# | <span style="color:#B48EAD">⬤</span> | `#B48EAD` | <font color=#B48EAD>CSS Constant Other Color RGB Value, Token Debug</font> |
# | <span style="color:#ECEFF4">⬤</span> | `#ECEFF4` | <font color=#ECEFF4>Punctuation, Punctuation Section, JavaScript Interpolated String Template Punctuation Functions</font> |
# | <span style="color:#D8DEE9">⬤</span> | `#D8DEE9` | <font color=#D8DEE9>Invalid Deprecated, Invalid Illegal, Variable Other, Variable Parameter, Markdown String Other Link Description/Title</font> |
# | <span style="color:#78849b">⬤</span> | `#78849b` | <font color=#78849b>Comment, punctuation.definition.comment</font> |
#
# ---
#
# | 顏色 | HEX | 對應的 `UI` 元件 |
# |------|-----|---------------|
# | <span style="color:#bf616a">⬤</span> | `#bf616a` | <font color=#bf616a>editorError.foreground, editorGutter.deletedBackground, errorForeground</font> |
# | <span style="color:#ebcb8b">⬤</span> | `#ebcb8b` | <font color=#ebcb8b>editorGutter.modifiedBackground, terminal.ansiBrightYellow, terminal.ansiYellow</font> |
# | <span style="color:#a3be8c">⬤</span> | `#a3be8c` | <font color=#a3be8c>editorGutter.addedBackground, terminal.ansiBrightGreen, terminal.ansiGreen</font> |
# | <span style="color:#8fbcbb">⬤</span> | `#8fbcbb` | <font color=#8fbcbb>gitDecoration.submoduleResourceForeground, terminal.ansiBrightCyan, terminal.ansiCyan</font> |
# | <span style="color:#88c0d0">⬤</span> | `#88c0d0` | <font color=#88c0d0>activityBar.activeBorder, editorBracketMatch.border, progressBar.background</font> |
# | <span style="color:#81a1c1">⬤</span> | `#81a1c1` | <font color=#81a1c1>editorOverviewRuler.infoForeground, terminal.ansiBrightBlue, terminal.ansiBlue</font> |
# | <span style="color:#5e81ac">⬤</span> | `#5e81ac` | <font color=#5e81ac>gitDecoration.conflictingResourceForeground, inputOption.activeBackground, statusBar.debuggingBackground</font> |
# | <span style="color:#b48ead">⬤</span> | `#b48ead` | <font color=#b48ead>terminal.ansiBrightMagenta, terminal.ansiMagenta</font> |
# | <span style="color:#a08bb1">⬤</span> | `#a08bb1` | <font color=#a08bb1>activityBar, background</font> |
# | <span style="color:#876d9d">⬤</span> | `#876d9d` | <font color=#876d9d>statusBar.background, titleBar.activeBackground, statusBarItem.remoteBackground</font> |
# | <span style="color:#eceff4">⬤</span> | `#eceff4` | <font color=#eceff4>terminal.ansiBrightWhite</font> |
# | <span style="color:#e7e7e7">⬤</span> | `#e7e7e7` | <font color=#e7e7e7>statusBar.foreground, titleBar.activeForeground, statusBarItem.remoteForeground</font> |
# | <span style="color:#e5e9f0">⬤</span> | `#e5e9f0` | <font color=#e5e9f0>terminal.ansiWhite</font> |
# | <span style="color:#d9d0c6">⬤</span> | `#d9d0c6` | <font color=#d9d0c6>activityBarBadge.background</font> |
# | <span style="color:#d8dee9">⬤</span> | `#d8dee9` | <font color=#d8dee9>editor.foreground, button.foreground, input.foreground, list.focusForeground</font> |
# | <span style="color:#4c566a">⬤</span> | `#4c566a` | <font color=#4c566a>button.hoverBackground, editorCodeLens.foreground, editorLineNumber.foreground</font> |
# | <span style="color:#292e39">⬤</span> | `#292e39` | <font color=#292e39>dropdown.background, editorHoverWidget.background, input.background, statusBar.noFolderBackground</font> |
# | <span style="color:#1d2129">⬤</span> | `#1d2129` | <font color=#1d2129>editor.background, editorGroupHeader.noTabsBackground, terminal.background</font> |
# | <span style="color:#15202b">⬤</span> | `#15202b` | <font color=#15202b>activityBar.foreground, activityBarBadge.foreground</font> |
# | <span style="color:#00000066">⬤</span> | `#00000066` | <font color=#00000066>scrollbar.shadow, widget.shadow</font> |
